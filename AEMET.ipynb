# %% [markdown]
# # Extracción de datos api AEMTE
#
# En primer lugar se realiza una petición al recurso de la API para obtener todas las estaciones meteorológicas que tiene AEMTE

# %%
import requests
import json
import time

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtcml2YXNAaXRlbGxpZ2VudC5lcyIsImp0aSI6IjIyMzUzZjk5LTcwNDgtNGEwNi04ODU4LWIzYWVkNTY4MzMxNCIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTI5MTQ5Mjc0LCJ1c2VySWQiOiIyMjM1M2Y5OS03MDQ4LTRhMDYtODg1OC1iM2FlZDU2ODMzMTQiLCJyb2xlIjoiIn0.tI_jCD1EGA7bD3y-C9VCGRjUUQND_SEeyqV5oxtQv94"}
headers = {
    'cache-control': "no-cache"
    }


response = requests.request("GET",  "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/", headers=headers, params=querystring)
data = json.loads(response.text)
response = requests.request("GET", data["datos"], headers=headers)
print(response.text)
estaciones = json.loads(response.text)
# Out:
# [ {
#   "latitud" : "413515N",
#   "provincia" : "BARCELONA",
#   "altitud" : "74",
#   "indicativo" : "0252D",
#   "nombre" : "ARENYS DE MAR",
#   "indsinop" : "08186",
#   "longitud" : "023224E"
# }, {
#   "latitud" : "411734N",
#   "provincia" : "BARCELONA",
#   "altitud" : "4",
#   "indicativo" : "0076",
#   "nombre" : "BARCELONA AEROPUERTO",
#   "indsinop" : "08181",
#   "longitud" : "020412E"
# }, {
#   "latitud" : "412506N",
#   "provincia" : "BARCELONA",
#   "altitud" : "408",
#   "indicativo" : "0200E",
#   "nombre" : "BARCELONA, FABRA",
#   "indsinop" : "",
#   "longitud" : "020727E"
# }, {
#   "latitud" : "412326N",
#   "provincia" : "BARCELONA",
#   "altitud" : "6",
#   "indicativo" : "0201D",
#   "nombre" : "BARCELONA",
#   "indsinop" : "08180",
#   "longitud" : "021200E"
# }, {
#   "latitud" : "414312N",
#   "provincia" : "BARCELONA",
#   "altitud" : "291",
#   "indicativo" : "0149X",
#   "nombre" : "MANRESA",
#   "indsinop" : "08174",
#   "longitud" : "015025E"
# }, {
# ...

# %% [markdown]
# Una vez se tienen todas las estaciones, y conocemos el indicativo de cada una de ellas, se puede usar el recurso de la API para obtener las observaciones.

# %%
for estacion in estaciones:    
    response = requests.request("GET", "https://opendata.aemet.es/opendata/api/observacion/convencional/datos/estacion/"+estacion["indicativo"], headers=headers, params=querystring)
    print(response.text)
    data = json.loads(response.text)
    
    #Si la respuesta ha sido ok continuamos
    if data["estado"] == 200: 
        response = requests.request("GET", data["datos"], headers=headers)
        print(estacion["nombre"])
        print(response.text)
        
    time.sleep(2)
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/932fa965",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/55c2971b"
# }
# ARENYS DE MAR
# [ {
#   "idema" : "0252D",
#   "lon" : 2.54,
#   "fint" : "2021-06-04T15:00:00",
#   "prec" : 0.0,
#   "alt" : 74.0,
#   "vmax" : 5.3,
#   "vv" : 0.6,
#   "dv" : 118.0,
#   "lat" : 41.587223,
#   "dmax" : 48.0,
#   "ubi" : "ARENYS DE MAR",
#   "hr" : 55.0,
#   "tamin" : 22.2,
#   "ta" : 23.0,
#   "tamax" : 25.8,
#   "tpr" : 13.5,
#   "rviento" : 59.0
# }, {
#   "idema" : "0252D",
#   "lon" : 2.54,
#   "fint" : "2021-06-04T16:00:00",
#   "prec" : 0.0,
#   "alt" : 74.0,
#   "vmax" : 3.8,
#   "vv" : 0.9,
#   "dv" : 98.0,
#   "lat" : 41.587223,
#   "dmax" : 126.0,
#   "ubi" : "ARENYS DE MAR",
#   "hr" : 57.0,
#   "tamin" : 22.7,
#   "ta" : 23.1,
#   "tamax" : 24.4,
#   "tpr" : 14.1,
#   "rviento" : 54.0
# }, {
#   "idema" : "0252D",
#   "lon" : 2.54,
#   "fint" : "2021-06-04T17:00:00",
# ...
